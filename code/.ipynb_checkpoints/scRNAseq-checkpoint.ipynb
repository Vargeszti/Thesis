# %%
import pandas as pd
import umap

from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %%
data = pd.read_csv('../data/scrnaseq/test_mat.csv', sep=',', header=0, index_col=0)

# %%
meta = pd.read_csv('../data/scrnaseq/meta_data_smartseq2.csv', sep=',', header=0, index_col=0)

# %%
data.head()
# Out:
#           SMARTseqFINAL_allLanes_AACATCCGAAGAGAGG  \
# TSPAN6                                        0.0
# DPM1                                          0.0
# SCYL3                                         0.0
# C1orf112                                      0.0
# FGR                                           0.0
#
#           SMARTseqFINAL_allLanes_AACATCCGCAGTATCG  \
# TSPAN6                                   0.000000
# DPM1                                     0.000000
# SCYL3                                    0.000000
# C1orf112                                 0.000000
# FGR                                      3.710542
#
#           SMARTseqFINAL_allLanes_AACATCCGCCTCCTAA  \
# TSPAN6                                   0.000000
# DPM1                                     0.000000
# SCYL3                                    0.000000
# C1orf112                                 0.000000
# FGR                                      3.304465
#
# ...

# %%
meta.head()
# Out:
#                                             nnet2     ident  technology
# cell
# SMARTseqFINAL_allLanes_AACATCCGAAGAGAGG  NK cells  NK cells  Smart-Seq2
# SMARTseqFINAL_allLanes_AACATCCGCAGTATCG  NK cells  NK cells  Smart-Seq2
# SMARTseqFINAL_allLanes_AACATCCGCCTCCTAA   B cells   B cells  Smart-Seq2
# SMARTseqFINAL_allLanes_AACATCCGCGAATCTG  NK cells  NK cells  Smart-Seq2
# SMARTseqFINAL_allLanes_AACATCCGCGCCTATA  NK cells  NK cells  Smart-Seq2

# %%
model = umap.UMAP()

# %%
data_umap = model.fit_transform(data.T)

# %%
data_umap = pd.DataFrame(data_umap, index=data.columns, columns=['UMAP1', 'UMAP2'])

# %%
data_umap = data_umap.loc[meta.index]

# %%
data_umap['Cell'] = meta.loc[data_umap.index, 'nnet2']

# %%
data_umap.head()
# Out:
#                                             UMAP1     UMAP2      Cell
# cell
# SMARTseqFINAL_allLanes_AACATCCGAAGAGAGG -3.089356 -2.703920  NK cells
# SMARTseqFINAL_allLanes_AACATCCGCAGTATCG -3.045402 -3.563882  NK cells
# SMARTseqFINAL_allLanes_AACATCCGCCTCCTAA  3.007967  1.748989   B cells
# SMARTseqFINAL_allLanes_AACATCCGCGAATCTG -2.825014 -3.042851  NK cells
# SMARTseqFINAL_allLanes_AACATCCGCGCCTATA -2.743412 -2.690962  NK cells

# %%
sns.scatterplot(x=data_umap['UMAP1'], y=data_umap['UMAP2'], hue=data_umap['Cell'])

# %%
nn = pd.read_csv('../data/ligand_target_matrix.csv', sep=',', header=0, index_col=0)

# %%
nn.head()
# Out:
#              CXCL1     CXCL2     CXCL3     CXCL5      PPBP     CXCL6  \
# A1BG      0.000353  0.000404  0.000373  0.000308  0.000263  0.000273
# A1BG-AS1  0.000165  0.000151  0.000158  0.000132  0.000123  0.000118
# A1CF      0.000579  0.000460  0.000390  0.000329  0.000321  0.000309
# A2M       0.000603  0.000600  0.000516  0.000452  0.000459  0.000416
# A2M-AS1   0.000089  0.000082  0.000075  0.000049  0.000051  0.000048
#
#              CXCL8     CXCL9    CXCL10    CXCL11  ...   PCDHGB1      CDH6  \
# A1BG      0.000414  0.000298  0.000416  0.000308  ...  0.000303  0.000319
# A1BG-AS1  0.000217  0.000141  0.000170  0.000137  ...  0.000160  0.000164
# A1CF      0.000483  0.000370  0.000393  0.000358  ...  0.000425  0.001664
# A2M       0.000703  0.000541  0.000616  0.000497  ...  0.000473  0.000508
# A2M-AS1   0.000138  0.000055  0.000061  0.000080  ...  0.000032  0.000078
#
#               CDH9     CDH12     CDH18   PCDHB16    PCDHA7    PCDHA6  \
# ...

# %%
data_norm = ((data.T - data.mean(1)) / data.std(1)).T

# %%
common_genes = list(set(nn.index) & set(data.index))

# %%
nn = nn.loc[common_genes]
data = data.loc[common_genes]

# %%
data_nn = pd.concat([nn,data], 1)

# %%
sim_nn_data = data_nn.corr()

# %%
sim_nn_data = sim_nn_data.loc[nn.columns, data.columns]

# %%
sim_nn_data = sim_nn_data.T

# %%
sim_nn_data = sim_nn_data.loc[meta.index]
sim_nn_data['Cell'] = meta.loc[sim_nn_data.index, 'nnet2']

# %%
average_activity = sim_nn_data.groupby('Cell').mean()

# %%
average_activity
# Out:
#                       CXCL1     CXCL2     CXCL3     CXCL5      PPBP     CXCL6  \
# Cell
# B cells            0.059484  0.068320  0.062732  0.062231  0.059698  0.058102
# CD14+ Monocytes    0.075869  0.084948  0.079943  0.078097  0.075237  0.074979
# CD4 T cells        0.057473  0.061347  0.058767  0.059005  0.056950  0.055116
# CD8 T cells        0.058423  0.064717  0.059596  0.060024  0.056324  0.055293
# Dendritic cells    0.099504  0.116248  0.108494  0.101770  0.100108  0.104110
# FCGR3A+ Monocytes  0.095573  0.108763  0.101166  0.096415  0.091753  0.095783
# HEK cells          0.066812  0.059834  0.068836  0.065302  0.069862  0.061575
# NK cells           0.060280  0.068554  0.062547  0.061623  0.058243  0.058868
#
#                       CXCL8     CXCL9    CXCL10    CXCL11  ...   PCDHGB1  \
# Cell                                                       ...
# B cells            0.054850  0.061938  0.074466  0.062545  ...  0.068469
# ...

# %%
average_activity.loc['B cells'].sort_values().tail(20)
# Out:
# SCG2       0.082298
# IFNB1      0.083410
# CSHL1      0.084934
# HLA-F      0.085053
# GDNF       0.086026
# HLA-DMA    0.086388
# CCL26      0.087482
# SECTM1     0.087725
# PTPRC      0.088294
# IL17F      0.091066
# CNTN2      0.091864
# CD34       0.093153
# CCL8       0.093331
# SLIT2      0.093801
# PRLH       0.095710
# IL17A      0.097799
# TNFSF18    0.097975
# HLA-G      0.105794
# ASIP       0.113954
# CLDN24          NaN
# Name: B cells, dtype: float64

# %%
average_activity.loc['CD14+ Monocytes'].sort_values().tail(20)
# Out:
# CD226      0.097141
# HLA-DMA    0.097395
# IL7        0.098089
# CCL4       0.098833
# CSHL1      0.099300
# ICAM2      0.099449
# IL17F      0.099554
# GDNF       0.100815
# CCL8       0.102253
# PTPRC      0.103513
# CNTN2      0.103832
# CD34       0.106271
# PRLH       0.106412
# SECTM1     0.107155
# SLIT2      0.110271
# IL17A      0.110569
# TNFSF18    0.111836
# HLA-G      0.112902
# ASIP       0.116804
# CLDN24          NaN
# Name: CD14+ Monocytes, dtype: float64

# %%
average_activity.loc['HEK cells'].sort_values().tail(20)
# Out:
# SECTM1     0.102527
# CNTN2      0.102716
# TNFSF18    0.103683
# ROBO2      0.105002
# ADAM23     0.107003
# ZP3        0.110251
# MANF       0.110500
# IL17C      0.111056
# FLRT3      0.111226
# TPH1       0.112184
# FLRT2      0.112705
# CDHR2      0.112888
# RLN1       0.113503
# CDH13      0.113909
# SDK1       0.114038
# CD34       0.120233
# SLIT2      0.124806
# PTDSS1     0.127939
# CD6        0.134720
# CLDN24          NaN
# Name: HEK cells, dtype: float64

# %%
average_activity.loc['CD4 T cells'].sort_values().tail(20)
# Out:
# IL16       0.080724
# CCL8       0.081959
# IL7        0.082388
# GDNF       0.082710
# CSHL1      0.083023
# PTPRC      0.083384
# SECTM1     0.085324
# TIGIT      0.085436
# CD6        0.085451
# HLA-G      0.085986
# ICAM2      0.086163
# CD226      0.087382
# CNTN2      0.088126
# CD34       0.089889
# PRLH       0.090515
# IL17A      0.090574
# TNFSF18    0.096594
# ASIP       0.100364
# SLIT2      0.102963
# CLDN24          NaN
# Name: CD4 T cells, dtype: float64
